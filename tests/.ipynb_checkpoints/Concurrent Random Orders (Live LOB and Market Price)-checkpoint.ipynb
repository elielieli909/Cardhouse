# %%
# This is a testing script for my exchange server
import requests
import threading
import random
import time
import matplotlib.pyplot as plt
import json

# %%
URL = "http://localhost:8080/api/order"
URL_price = "http://localhost:8080/api/1/data/marketPrice"

symbols = ['DOUG', 'TRAV', '24k', 'ART']
# qty will be within a range
types = ['market', 'limit']
sides = ['buy', 'sell']
#limit will be a range

# %%
def FiftyRandomOrders():
    for i in range(50):
        symbol = random.choice(symbols)
        qty = random.randrange(400)
        o_type = random.choice(types)
        side = random.choice(sides)
        limit = random.randrange(70)
        
        print("Order", i, ":", side, "ing ", qty, " shares of DOUG at ", o_type)

        body = {
            'symbol': 'DOUG',
            'qty': qty,
            "type": 'market',
            "side": str(side),
            "limit": limit,
            "time_in_force": "day"
        }

        r = requests.post(url=URL, json=body)
        #time.sleep(1)
        r2 = requests.get(url=URL_price)
        
        print(r2.json(), '\n')
        
# Collect market prices
def get_prices():
    prices = []
    for i in range(500):
        r = requests.get(url=URL_price)
        price = r.json()
        prices.append(price)
        time.sleep(0.1)
    return prices

# %%
#Start 10 threads making concurrent requests
threads = []
for i in range(10):
    thread = threading.Thread(target=FiftyRandomOrders)
    threads.append(thread)
    
for thread in threads:
    thread.start()
# FiftyRandomOrders()
prices = get_prices()
# Out:
# Order 0 : sell ing  385  shares of DOUG at  market
# Order Order 00Order 0 : buy ing  328  shares of DOUG at  market
#   :Order 0 : buy ing  348  shares of DOUG at  market
#  buy ing  257  shares of DOUG at  limit
# : buyOrder  ing  96  shares of DOUG at  market
# Order0 : buy ing  208  shares of DOUG at   limit0Order : buy ing  72  shares of DOUG at  limit
#
# Order 00 : sell ing  207  shares of DOUG at  market
#  Order 0 : sell ing  122  shares of DOUG at  limit
# : sell ing  10  shares of DOUG at  market
# 46
#
# 46
#
# Order 1 : sell Order 1 : buy ing  367  shares of DOUG at  limit
# ing 35 35
#
# Order 1 : buy ing 35
#
# Order 1 : buy ing  275  shares of DOUG at  limit
#  35
#
# Order 1 : buy ing  100  shares of DOUG at  limit
# 25522535
#   shares of DOUG at  limit
#  35
#
#
# Order 1 : buy ing  81Order shares of DOUG at   1 : sell ing  271  shares of DOUG at  limit
#  shares of DOUG at   35
#
# Order 1 : sell ing  377  shares of DOUG at  market
# 35
#
# Order 1 : buy ing  303  shares of DOUG at  market
# market
#
#  limit
#
# Order 1 : buy ing  52  shares of DOUG at  market
# 49
#
# Order 2 : buy ing  137  shares of DOUG at  limit
# 51
#
# Order 2 : buy ing  95  shares of DOUG at  limit
# 51
#
# Order 2 : buy ing  337  shares of DOUG at  market
# 51 51
#
# Order 2 : sell ing
#
# 51
#
# Order 2 : sell ing  129   shares of DOUG at  limit326Order51
#
# Order 2
# : sell ing  2  shares of DOUG at  limit
#  51 2
#
# Order 2 : sell ing  358  shares of DOUG at  limit
#   shares of DOUG at : sell ing  321  shares of DOUG at  52
#
# Order 2 : buy ing  366  shares of DOUG at  market
# 51
#
# Order 2 : buy ing  17  shares of DOUG at  marketmarket
#  limit
#
# 53
#
# Order 3 : sell ing  275  shares of DOUG at  limit
# 53
#
# Order 3 : sell ing  29  shares of DOUG at  limit
# 53
#
# Order 3 : sell ing  125  shares of DOUG at  limit
# 53
#
# Order 3 : sell ing  359  shares of DOUG at  market
# 27
#
# Order 3 :27  25sell
#
#
# ing Order 3 : sell ing  54  shares of DOUG at
# Order 3  limit
# : buy ing  8  shares of DOUG at  limit
#  104  shares of DOUG at  limit
# 21
#
# Order 4 : buy ing  359  shares of DOUG at  market
# 21
#
# Order 3 : buy ing  130  shares of DOUG at  limit
# 21 21
#
# Order 4
#
# :Order21   sell4 : buy ing  280  shares of DOUG at  limit
#  21
#
# Order 4 : buy ing  137  shares of DOUG at  market
#  ing
#
# Order 3 : buy ing  3  shares of DOUG at  market
#  2135  shares of DOUG at  market
#
#
# Order 3 : buy ing  32  shares of DOUG at  market
# 5656
#
#
#
# Order 4 : buy ing  361  shares of DOUG at  limit
# Order56
#
# Order 4  4 : sell ing  212  shares of DOUG at  market
# : sell ing  192  shares of DOUG at  market
# 57 5757
#
#
# Order 4 : buy ing
#
# Order 5 : sell ing  279  shares of DOUG at  market
#
# Order 5 : buy ing  164  shares of DOUG at  limit
# 9357  shares of DOUG at   57
#
# Order 4 : selllimit
#
# Order 5 :
#  buy ing  61  shares of DOUG at  market
# ing  320  shares of DOUG at  market
# 5757
#
# Order 5 : buy ing  378  shares of DOUG at  limit
#
#
# Order 4 : buy ing  122  shares of DOUG at  market
# 58
#
# Order 5 : sell ing  365  shares of DOUG at  market
# 58
#
# Order 5 : buy ing  74  shares of DOUG at  58
#
# Order 5 : buy ing  203  shares of DOUG at  market
# limit58
#
#
# Order 6 : sell ing  17316
# 13  shares of DOUG at  market
#
#
#
# Order 5 13
#
# Order 6 : Ordersell  ing 6: sell ing  322  shares of DOUG at  limit
#   31  shares of DOUG at  market
# : buy ing  228  shares of DOUG at  11
#
# Order 6 : buylimit
#  ing  105  shares of DOUG at  market
# 11
#
# Order 5 : sell ing 11 11207  11  shares of DOUG at
#
#
#
# Order 6 : sell ing  397 market
#  shares of DOUG at  limit
#
# OrderOrder 6 : sell ing  313  shares of DOUG at  market
# 10
#
#
# Order 5 : buy ing  89  shares of DOUG at  limit
# 10
#
# Order 7 : sell ing  219  shares of DOUG at  market
# 6 : sell ing  384  shares of DOUG at  market
# 60
#
# Order 6 : buy 1010
#
# Order 7 : buy ing  84  shares of DOUG at  limit
#  ing
#  201  shares of DOUG at  market
#
# Order 60 7
#
# Order 7 : sell ing  267  shares of DOUG at  market
#  : 60
#
# Order 7 sell ing  159  shares of DOUG at  limit
# : sell ing  362  shares of DOUG at  limit
# 60
#
# 60
#
# Order 7 : buy ing  27  shares of DOUG at  market
# 60
#
# Order 8 Order 6 : buy ing  259  shares of DOUG at  market
# : buy ing  248 60 shares of DOUG at  60
#
# Order 6 : buy ing  8  shares of DOUG at  limit
#  limit
#
#
# Order 7 : sell ing  124  shares of DOUG at  market
# 60
#
# Order 8 62
#
# Order 8 : sell ing : buy ing  117  shares of DOUG at  limit
#  131  shares of DOUG at  market
# 6262
#
# Order 7
# 62
#
# Order 7 : sell ing  134  shares of DOUG at  market
# :
# 62
#
# Order 8 buy ing  210  shares of DOUG at  limit
#  Order:  8sell :  ing  sell ing  62335341  shares of DOUG at  limit62
#
# Order 8 : buy ing  253  shares of DOUG at  limit62
#
# Order 7 : buy ing  263
#
#  shares of DOUG at  shares of DOUG at  limit
#
#  limit
#
# 62Order
#
# Order 9 : buy ing  232 8  shares of DOUG at :  buy ing  94 market
#  shares of DOUG at  market
# 64
#
# Order 9 : buy ing  399  shares of DOUG at  market
# 64 64
#
# Order 9 : sell ing  57  shares of DOUG at  market
#
#
# Order 8 : sell ing  166  shares of DOUG at  limit
# 65
#
# Order 9 : sell ing  346  shares of DOUG at  limit
# 6565
#
# Order 9 : buy ing  228  shares of DOUG at  limit
#
#
# Order 8 : buy ing  142  shares of DOUG at  market
# 65
#
# Order 9 65:
#
# Order 8 : buy ing  93  shares of DOUG at  limit
#  sell ing  121  shares of DOUG at  market
# 6565
#
# Order 9 : buy ing  360  shares of DOUG at  limit
#
#
# Order 10 : sell ing  78  shares of DOUG at  limit
# 65
#
# Order 10 66
#
# Order 9 : :buy ing  131  shares of DOUG at  market
#  66buy
#
# Order  1066ing  21  shares of DOUG at  limit
#
#
# Order 9 : buy ing  317  shares of DOUG at  : sell ing  394  shares of DOUG at  limit
#  limit
# 66
#
# Order 9 : sell ing  380  shares of DOUG at  limit
# 66
#
# 67
#
# Order 11 : buy ing  371 Order 10 : sell ing  95  shares of DOUG at  limit
#  shares of DOUG at  limit
# 67
#
# Order 10 : buy ing  82  shares of DOUG at  market
# 67
#
# Order 10 : buy ing  186  shares of DOUG at  limit
# 67
#
# Order 10 : buy ing  298  shares of DOUG at  limit
# 6767
#
# Order 10 : sell ing  214  shares of DOUG at  market
#
#
# Order 11 : sell ing  283  shares of DOUG at  market
# 67
#
# Order 10 : sell ing  345  shares of DOUG at  market
# 67
#
# Order 11 : sell ing  61  shares of DOUG at  market
# 70
#
# Order 12 : buy ing  143  shares of DOUG at  limit
# 70
#
# Order 11 : sell ing  30  shares of DOUG at  market
# 70
#
# Order 11 : buy ing  114  shares of DOUG at  limit
# 7070
#
# Order 11 : buy ing  76  shares of DOUG at  limit
#
#
# Order 10 : buy ing  211  shares of DOUG at  limit
# 70
#
# Order 11 : 70
# buy
# Order 11  :ing  buy ing  106  shares of DOUG at  market
#  372  shares of DOUG at  limit
# 70
#
# Order 11 : buy ing  354  shares of DOUG at  limit
# 70
#
# 70
#
# Order 12 : sell ing  329  shares of DOUG at  limit
# Order 12 : sell ing  37070  shares of DOUG at  market
#
#
# Order 13 : sell ing  286  shares of DOUG at  limit
# 70
#
# Order 12 : buy ing  231  shares of DOUG at  limit
# 70
# 70
# Order 11 : 70
#
# Order 12 70
#
#  :
#
# Order 12 : sell ing  105  shares of DOUG at  marketOrder 12 : buy ing  125  shares of DOUG at  limit
# buy ing  27
#  70  shares of DOUG at  market
#  buy ing  186  shares of DOUG at
#
#  Order 12 : buy ing  107  shares of DOUG at  70
#
# Order 12 : buy ing  23370 market
#
# Order 13 : sell ing  352  shares of DOUG at  market
# market
#
#  shares of DOUG at  limit
# 70
#
# Order 13 : sell ing  87  shares of DOUG at  market
# 70
#
# Order 14 : buy ing  252  shares of DOUG at  limit
# 70
#
# Order 13 : buy ing  237  shares of DOUG at  market
# 70
#
# 70
#
# Order 13Order 14 :  : buy ing  28  shares of DOUG at  sellmarket
#  ing  134  shares of DOUG at  limit70
#
#
# Order 13 : buy ing  131  shares of DOUG at  market
# 70
#
# Order 13 : buy ing  355  shares of DOUG at  limit
# 70
#
# Order 12 70
#
# Order 13 : sell ing : buy ing  72  shares of DOUG at  limit70  70
#
# Order 15
#
# Order 15 : buy ing  330  shares of DOUG at
# 199 :  shares of DOUG at  market
#  7070
#
# Order 14 : sell ing  249  shares of DOUG at  limit
#
#
# Order 14 : sell ing  106  shares of DOUG at  market
# market70
#
# Order 13
# :buy buy 70 ing  ing  44  shares of DOUG at  market
#  124  shares of DOUG at  limit
#
#
# Order70
#
# Order 14 : sell ing  172  shares of DOUG at  limit
# 14 : sell ing  311  shares of DOUG at  limit
# 70
#
# Order 14 : sell ing  36  shares of DOUG at  limit
# 70
#
# Order 14 : buy ing  18  shares of DOUG at  market
# 70
#
# Order 15 : buy ing  345  shares of DOUG at  market
# 70
#
# Order 13 : sell ing  124  shares of DOUG at  limit
# 70
#
# Order 16 : buy ing  310  shares of DOUG at  market
# 70
#
# Order 16 : buy ing  24  shares of DOUG at  limit
# 70
#
# Order 15 : buy ing 70  70
#
# Order 14 : sell ing  161  shares of DOUG at  limit
#
#
# 233  shares of DOUG at  market
# Order 15 : buy ing  366  shares of DOUG at  70
#
# Order 15 : buy ing  229  shares of DOUG at  limit
# limit
# 70
#
# Order 1470
#
# Order 17 : sell ing  301  shares of DOUG at  market
#  : sell ing  343  shares of DOUG at  limit
# 7070
#
# Order 17 70
#
# : buy ing  356  shares of DOUG at  market
# Order 16 : sell ing  18  shares of DOUG at  limit
#
#
# Order 15 : sell ing  255  shares of DOUG at  limit
# 70
#
# Order 15 : buy ing  374  shares of DOUG at  market
# 70
#
# Order 18 : sell ing  272  shares of DOUG at  market
# 70
#
# Order 16 : buy ing  172  shares of DOUG at  limit
# 7070
#
# Order 15 : buy ing  163  shares of DOUG at  limit
#
#
# Order 7016
#
# Order 16 : sell ing  37  shares of DOUG at  limit
#  : buy ing  358  shares of DOUG at  market
# 70
#
# Order 18 : sell ing  12  shares of DOUG at  limit
# 70
#
# 70Order
# 70
#
# Order 16 : buy ing  275  shares of DOUG at  market
# 7015 : sell ing  106  shares of DOUG at  limit
#
# Order
#
# Order 17 : buy ing  302  shares of DOUG at  limit
#  19 : buy ing  309  shares of DOUG at  limit
# 7070
#
# Order 17 : buy ing  229  shares of DOUG at  limit
#  70
#
# Order 16 : buy ing  84  shares of DOUG at  market
#
#
# Order 16 : sell ing  27  shares of DOUG at  limit
# 70
#
# Order 19 : sell ing  316  shares of DOUG at  market
# 7070
#
# Order 16 : buy ing  179  shares of DOUG at  limit
#
#
# Order 17 : sell ing  338  shares of DOUG at  limit
# 70
#
# Order 17 : buy ing  44  shares of DOUG at  market
# 70
#
# Order 20 : buy ing  190  shares of DOUG at  market
# 70
#
# Order 17 : buy ing  214  shares of DOUG at  limit
# 70 70
#
#
# Order 20 : buy ing  212  shares of DOUG at  limit
# 70
#  Order
#
#  17 : sell ing  216  shares of DOUG at  Ordermarket70
#
# Order 17  18:
#  : 70
#
# Order 18 : buy ing  361  shares of DOUG at  market
# sell ing  93  shares of DOUG at  market
# buy ing  342  shares of DOUG at  market
# 70
#
# Order 17 : buy ing  368  shares of DOUG at  market
# 70
# 70
#
# Order 18
# Order 18 : sell ing  83  : buy ing  273  shares of DOUG at  market
#  shares of DOUG at 70
#
# Order 21 : buy ing  68 limit
#  shares of DOUG at  market
# 70
#
# Order 18 : 70
#
# Order 19 : buy ing  205  shares of DOUG at  limit
# sell ing  240  shares of DOUG at  70market
#
#
# Order 18 : buy ing  26  shares of DOUG at  market
# 7070
#
# Order 18 : buy  ing  120
#
#  shares of DOUG at 70
#
# Order 19 : sell ing  96  shares of DOUG at  limit
#  limit
# Order 21 : buy ing  389  shares of DOUG at  limit
# 70
#
# Order 18 :70
#
# Order 22 : buy ing  55  shares of DOUG at  limit
#  sell ing  45  shares of DOUG at  market
# 70
#
# Order 20 : sell ing 70
#
# Order 19 :  370sell  shares of DOUG at  market
# 70
#
# Order  19 ing  359  shares of DOUG at  market70
#
# Order 19 : buy ing : sell ing  73  shares of DOUG at  market
#
#  209  shares of DOUG at  market
# 70
#
# Order 19 : sell ing  126  shares of DOUG at  market
# 70
# 70
#
# Order 19 :
# Order 20 : sell ing  sell ing  364  310  shares of DOUG at  market
#  shares of DOUG at 70
#
# Order  22 : sell ing  202  shares of DOUG at  limit
# market
# 70
#
# Order 23 : sell ing  22770
#
# Order 20 : buy ing  12  shares of DOUG at  limit
#   shares of DOUG at  market
# 70
#
# Order 19 : buy ing  309  shares of DOUG at  limit
# 70
# 70
# Order 20 : sell ing  165  shares of DOUG at  limit
#
# Order 20 : buy ing  10  shares of DOUG at  limit
#
# 70
#
# Order 21 : sell ing  338  shares of DOUG at  market
# 70
#
# Order 20 : sell ing  147  shares of DOUG at  70
#
# Order 20 : sell ing  271  shares of DOUG at  market
# 70market
#
#
# Order 23 : sell ing  214  shares of DOUG at  limit
# 70
#
# Order 21 : buy ing  47  shares of DOUG at  market
# 70
#
# Order 21 : buy ing  335  shares of DOUG at 70
#
# Order 20  market
# : sell ing  141  shares of DOUG at  market
# 70
#
# Order 21 : buy ing  194  shares of DOUG at  limit
# 70
#
# Order 24 : buy ing 70
#
# Order 21 : buy ing  67  shares of DOUG at  limit
# 70 70 36
#
#
# Order 22 : buy ing  281  shares of DOUG at  market
#
# Order 21 : buy ing  12  shares of DOUG at  market
#   shares of DOUG at 70
#
# Order 24 : sell ing  183  shares of DOUG at  limit
#  market
# 70
#
# Order 22 : buy ing  53  shares of DOUG at  limit
# 70
#
# Order 22 : sell ing 70
#
# Order 21  :397  shares of DOUG at  limit
#  sell ing  337  shares of DOUG at  market
# 70
#
# Order 25 : buy ing  223  shares of DOUG at  limit
# 70
#
# Order 21 : sell ing  241  shares of DOUG at  limit
# 70
#
# Order 22 :70
#
# Order 23 : buy ing  353  shares of DOUG at  market
#  sell 70
#
# Order 22ing 70
#
# Order 25 : buy ing  182  shares of DOUG at  limit
#  192  shares of DOUG at  limit
#  70
#
# Order 22 : sell ing  87  shares of DOUG at  limit
# : buy ing  238  shares of DOUG at  limit
# 70
#
# Order 23 : buy ing  256  shares of DOUG at  limit
# 7070
#
# Order 23 : buy ing  170  shares of DOUG at  limit
#
# 70
#
#
# OrderOrder 22 : sell ing  68  shares of DOUG at  limit
#  26 : buy ing  232  shares of DOUG at  limit
# 70
#
# Order 22 : buy ing  135  shares of DOUG at  market
# 70
#
# Order 23 : sell ing  316  shares of DOUG at  market
# 7070
#
# Order 24 : sell ing  280  shares of DOUG at  market
#
# 70
#
# Order 23 : buy ing  397  shares of DOUG at  market
#
# Order70
#
# Order 24 : buy ing  53  shares of DOUG at  market
#  26 70
#
# Order 23 : sell ing  204  shares of DOUG at  limit
# :7070
#
# Order 27 : sell  ing  370 buy ing  30  shares of DOUG at  market
#  70 shares of DOUG at  limit
#
#
# Order 24 : buy ing  130  shares of DOUG at  limit
#
#
# Order 23 : sell ing  218  shares of DOUG at  limit
# 70
#
# Order 23 : buy ing  80  shares of DOUG at  limit
# 70
#
# Order 24 : sell ing  168  shares of DOUG at  limit
# 70
#
# Order 25 : sell ing  315  shares of DOUG at  market
# 70
#
# Order 25 : buy ing  373  shares of DOUG at  market
# 70
#
# Order 2470
#
# Order 25 : sell ing  276  shares of DOUG at  market
#  : sell ing  259  shares of DOUG at  limit
# 70
#
# Order 24 : buy ing  51  shares of DOUG at  market
# 70
#
# Order 27 : sell70
#
# Order 24 : buy ing  291  shares of DOUG at   ing  223  shares of DOUG at  market
# 70limit
#
# Order 28 : buy ing  234  shares of DOUG at  limit
#
# 70
#
# Order 24 : sell ing  141  shares of DOUG at  limit
# 70
#
# Order 26 : sell ing  165  shares of DOUG at  70market
#
#
# Order 25 : buy ing  6370
#
# Order 26 : buy ing  20870   shares of DOUG at  market
#  shares of DOUG at  limit
#
#
# Order 25 : buy ing  143  shares of DOUG at  limit
# 70
#
# Order 28 :70 70 buy 70
#  ing  272  shares of DOUG at  limit
#
#
# Order 25 : sell ing  35870
#  70
#
#
# Order 25 : sell ing  30  shares of DOUG at  limit
#
#
# Order  shares of DOUG at 25
# Order limit
# Order 26 : buy ing  226  shares of DOUG at  limit
#  29 : sell ing  14  shares of DOUG at  limit
#  : sell ing  388  shares of DOUG at  market
# 70
#
# Order 26 : buy ing  208  shares of DOUG at  market
# 70
#
# Order 29 : sell ing  8  shares of DOUG at  limit
# 70
#
# Order70
#
# Order 27 : sell ing  267 70
#
# Order 27 : sell ing  390  shares of DOUG at  limit
#  shares of DOUG at  market
#  27 : sell ing  237  shares of DOUG at  limit70
#
#
# Order 26 : buy ing  189  shares of DOUG at  market
# 70
#
# Order 26 : sell ing  284  shares of DOUG at  limit
# 70
#
# Order 30 : sell ing  39  shares of DOUG at  limit
# 70
#
# Order 26 : sell ing  216  shares of DOUG at  market
# 70
#
# Order 26 : buy ing  383  shares of DOUG at  limit
# 70
#
# Order 27 : buy ing  161  shares of DOUG at  market
# 70
#
# Order 28 : sell ing  251  shares of DOUG at  limit
# 70
#
# Order 28 : sell ing  327  shares of DOUG at  market
# 70
#
# Order 27 : sell ing  290  shares of DOUG at  market
# 70
#
# Order 30 : buy ing  373  shares of DOUG at  market
# 70
#
# Order 27 : sell ing  381  shares of DOUG at  market
# 70
#
# Order 28 :7070 sell ing  251  shares of DOUG at  limit
#
#
# Order 31 : buy
# 70ing  283  shares of DOUG at
# Ordermarket
#
# Order 27  :7027 : buy ing  115  shares of DOUG at  market
#
#
# Order 28 : sell ing  176  shares of DOUG at  limit
#
# buy ing  267  shares of DOUG at  limit
# 70
# 70
#
# Order 29 : buy ing  86  shares of DOUG at  market
#
# Order 28 : buy ing  280  shares of DOUG at  market
# 70
#
# Order 31 : sell ing  398  shares of DOUG at  limit
# 70
#
# Order 29 : buy ing  356  shares of DOUG at  limit
# 70
#
# Order 28 : sell ing  107  shares of DOUG at  market
# 70
#
# Order 29 : buy ing  360  shares of DOUG at  market
# 70
#
# Order 28 : sell ing  392  shares of DOUG at  market
# 7070
#
# Order 28 :
#
# Order 29 : sell ing  110  shares of DOUG at  market
#  sell ing  280  shares of DOUG at  limit
# 70
#
# Order 32 : buy ing  288  shares of DOUG at  limit
# 70
#
# Order 30 : sell ing  102  shares of DOUG at  limit
# 70
#
# Order 29 : buy ing  139  shares of DOUG at  limit
# 70
#
# Order 32 : buy ing  249  shares of DOUG at  limit
# 70
#
# Order 29 : buy ing  279  shares of DOUG at  limit
# 70
#
# Order 30 : sell ing  12  shares of DOUG at  limit
# 70
#
# Order 29 : buy ing  1  shares of DOUG at  market
# 70
#
# Order 29 : buy ing  144  shares of DOUG at  market
# 7070
#
# Order 33 : buy ing  172  shares of DOUG at  limit
#
#
# Order 7070
#
# Order 31 : sell ing  275  shares of DOUG at  market
# 30  : sell ing  70
#
# Order 33 : buy ing  163  shares of DOUG at 2  shares of DOUG at  market
#  limit
#
#
# Order 30 : sell ing  2  shares of DOUG at  market
# 70
#
# Order 30 : sell ing  56  shares of DOUG at  market
# 7070
#
# Order 31 : sell ing  38  shares of DOUG at  market
# 70
# 70
#
# Order70
#
# Order
#
#  30 : sell ing  369  shares of DOUG at  limit
# 70
#
# Order 32 30
#  : sell:Order  Order 34 : sell ing  70 ing 223  shares of DOUG at  market
#  9  shares of DOUG at  market
# sell ing  364  shares of DOUG at  limit
#  70
#
# Order 34 : sell ing  231  shares of DOUG at  market
# 31
# Order  30 : sell ing  167  shares of DOUG at  limit
# : buy ing  116  shares of DOUG at  market
# 70
#
# Order 31 : sell ing  9  shares of DOUG at  market
# 70
#
# Order 31 : buy ing  246  shares of DOUG at  market
# 70
#
# Order 35 : buy ing  261  shares of DOUG at  limit
# 70 70
#
# Order70
# 70
#
# Order 33 : sell ing  4
#   shares of DOUG at  limit
# 31 : buy ing Order   32 : buy ing  62  shares of DOUG at  limit
# 215
#   shares of DOUG at  market
# 70
#
# Order 31 : sell ing  174
#  shares of DOUG at Order  market32
#  :7070 70
#
# Order 32 : sell ing
# 137
#
#
# 70 buy  shares of DOUG at  limit
# Order
# Order
# 32Order 36 : 35 : sell ing 70buy ing  93  shares of DOUG at  limit
#
#
# Order 31 : sell ing  267  shares of DOUG at  limit
#  197 :ing  buy70  ing  73  shares of DOUG at  limit
#
#
# Order 34 : shares of DOUG at  sell  138 limiting   347
#  shares of DOUG at  shares of DOUG at  market
# 7070
#
# Order
#
# Order 33 :  sell ing  108  shares of DOUG at  market
# 32  limit70 : buy ing  315  shares of DOUG at  market
#
#
#
# Order 33 : sell ing  184  shares of DOUG at  market
# 70
#
# Order 33 : sell ing  243  shares of DOUG at  limit
# 70
#
# Order 32 70 :70
#
# Order 34 : sell ing  239  shares of DOUG at  limit
# 70 70
#
# Order 36 : sell ing  293  shares of DOUG at  limit
#
#  70
#
# sell
# Order 37 : sell ing  342  shares of DOUG at  limit
# Order 32 : buy ing  345  shares of DOUG at  limit
#  ing   17  shares of DOUG at  market
#
#
# Order 35 70
#
# Order 34 :70  :sell ing  74  shares of DOUG at  limit
#
#
# Order 33 :  sell70  ing  160  shares of DOUG at  market
#
# sell ing  363  shares of DOUG at  limit
#
# Order 33 : buy ing  300  shares of DOUG at  market
# 70
#
# Order 33 : buy ing  165  shares of DOUG at  limit
# 70
#
# Order 33 : buy ing  1  shares of DOUG at  limit
# 70
#
# Order 34 : buy ing  141  shares of DOUG at  limit
# 7070
#
# Order 35 : sell ing  99  shares of DOUG at  market
#
#
# Order 37 : sell ing  195  shares of DOUG at  limit
# 70
# 70
#
# Order 38 : sell ing  205  shares of DOUG at  limit
#
# 70Order
#
# Order 36 : buy ing  136  shares of DOUG at  market
# 3570
# :
# Order sell  34ing   225  shares of DOUG at  :70
#
# Order 34 : buy ing  136  shares of DOUG at  market
#  market
# sell ing  70113  shares of DOUG at  market
#
#
# Order 34 : buy ing  31  shares of DOUG at  market
# 70
#
# Order 34 : sell ing  209  shares of DOUG at  market
# 70
#
# Order 38 : sell ing  138  shares of DOUG at  market
# 70 70
#
# Order 37
# : buy ing  367  shares of DOUG at
# market
# Order 36 : buy ing  187  shares of DOUG at  limit
# 70
#
# Order 35 : sell ing  81  shares of DOUG at  limit
# 70
#
# Order 39 : sell ing  251  shares of DOUG at  market
# 7070
#
# Order 35 : sell ing  49  shares of DOUG at  limit
#
# 70
#
# Order 36 : sell ing  365  shares of DOUG at  market
#
# Order 35 : sell 70ing  137  shares of DOUG at  market 7070
#
#
# Order 35 : buy ing  384  shares of DOUG at  limit
# 70
#
# Order 39 : sell ing  248  shares of DOUG at  market
#
#
# Order
#  37 : sell ing  10670
# Order 35 : sell ing  364  shares of DOUG at  market
#   shares of DOUG at  limit
#
#
# Order 36 : buy ing  134  shares of DOUG at  limit
# 70
#
# Order 37 : buy ing  146  shares of DOUG at  limit
# 70
#
# Order 40 : sell ing  390  shares of DOUG at  market
# 70
#
# Order 36 : buy ing  249  shares of DOUG at  70limit70
#
# Order 36 : sell ing  362  shares of DOUG at  limit
#
#  70
#
#
#
# Order 38 : sell ing  181  shares of DOUG at  Order 40 : market
# 70
#
# Order 37 : sell ing  333  shares of DOUG at  limit
# sell ing  71  shares of DOUG at  limit
# 70
#
# Order 36 : sell ing  232  shares of DOUG at  limit
# 70
#
# Order 38 : sell ing  358  shares of DOUG at  limit
# 70
#
# Order 37 : sell ing  142  shares of DOUG at  limit
# 70 7070
#
# Order 36 : buy ing  307  shares of DOUG at  limit
#
#
# Order 41 : sell ing  170  shares of DOUG at  limit
# 70
#
# Order 37 : sell ing  104  shares of DOUG at  market
#
#
# Order 38 : buy ing  7064  shares of DOUG at  limit
#
#
# Order 39 : buy ing  228  shares of DOUG at  limit
# 7070
#
# Order 3870 : buy ing  182  shares of DOUG at  market
#  70
#
# Order 41 : buy ing  309  shares of DOUG at
#
# Order 37 limit
# :
#
# Order 38 buy ing  87  shares of DOUG at  limit
# 70:  70
#
# Order 39 : buy ing  100  shares of DOUG at  limit
#  buy ing  21  shares of DOUG at  market
#
#
# Order 42 : buy ing  184  shares of DOUG at  market
# 70
#
# Order 37 : sell ing  222  shares of DOUG at  market
# 70
#
# Order 39 : sell ing  2370
#
# Order 38 : buy ing  382  shares of DOUG at  market
#   shares of DOUG at  market
# 70 70
#
# Order 38 : buy ing  372  shares of DOUG at  market
#
#
# Order 42 : buy70  ing
#
# Order 43 : sell ing  213  shares of DOUG at  market
# 7070
#
# Order 39 : sell ing  287  shares of DOUG at  market
#
#
# 156  shares of DOUG at  limit
# Order 40 70
#
# Order 38 : buy ing  363  shares of DOUG at  market
# 70
#
# Order 39 : buy:  buy70
#
# Order 40 : sell ing  29  shares of DOUG at  limit
# ing  143  shares of DOUG at  market
#  70
#
# Order 39ing  : buy ing  63  shares of DOUG at  market
#  241  shares of DOUG at  limit
# 70 70
#
# Order 44 : sell ing  130  shares of DOUG at  market
#
#
# Order 40 : buy ing  29  shares of DOUG at  limit
# 70
#
# Order 39 : sell ing  47  shares of DOUG at  market
# 70
#
# Order 43 : sell ing  93  shares of DOUG at  limit
# 70
#
# Order 40 : buy ing  191  shares of DOUG at  market
# 70
#
# Order 39 : sell ing  322  shares of DOUG at  market
# 7070
#
# Order 40 : buy ing  249  shares of DOUG at  market
#
#
# Order 41 : buy ing  393 70
#
# Order 45 : buy ing  232  shares of DOUG at  limit
#  shares of DOUG at  market
# 70
#
# Order 40 : buy ing  25  shares of DOUG at  market
# 70
#
# Order 41 : sell ing 70  255  shares of DOUG at  limit
#
#
# 70Order 41 : buy ing  220  shares of DOUG at  market
#  70
#
# Order 40 : buy ing  241  shares of DOUG at  market
#
#
# Order 41 : sell ing  342  shares of DOUG at  limit
# 70
#
# Order 44 : sell ing  36  shares of DOUG at  limit
# 70 70
#
# Order 42 : buy ing  310  shares of DOUG at  limit
#
# 70
#
# Order 41 : sell ing  179  shares of DOUG at  market
#
# 70
#
# Order 42 : buy ing  227  shares of DOUG at  market
# Order 40 : buy ing  153  shares of DOUG at  limit
# 70
#
# Order 41 : sell ing  114  shares of DOUG at  limit
# 70
#
# Order 4670
#
# Order 43 : sell ing  38  shares of DOUG at  market
#  : buy ing  8 70 shares of DOUG at
#
# Order 41 : 7070
#
# Order 42 : sell ing  226  shares of DOUG at  limit
#  limit
# buy
#
#  ing  332  shares of DOUG at  market
# Order 42 :70
#
# Order 42 : buy ing  271  shares of DOUG at  limit
# 70
#
# Order 43 : buy ing  76  shares of DOUG at  market
#  buy ing  153  shares of DOUG at  market
# 70
# 70
#
# Order 45
# Order 44 : buy ing  302  shares of DOUG at  limit
# : buy ing  384  shares of DOUG at  market
# 70
#
# Order 43 70:70
#
#
# Order 41buy
#  ing  267  shares of DOUG at  market
#  Order 44 : sell ing  58  shares of DOUG at  limit
# : buy ing  289  shares of DOUG at  limit
# 70
#
# Order 42 : buy ing  338  shares of DOUG at  market
# 7070  70
#
# Order 47 : buy ing  286  shares of DOUG at  market
#
#
#
#
# 70Order  42 : buy ing  244  shares of DOUG at  market
#
#
# Order Order 43 : buy ing  330  shares of DOUG at  limit
# 43 : sell ing  91  shares of DOUG at  limit
# 70
#
# Order 45 : sell ing  269  shares of DOUG at  limit
# 70
#
# Order 46 : buy ing  235  shares of DOUG at  limit
# 7070
#
# Order 42 : buy ing
#
# Order 2107043 : sell ing  276  shares of DOUG at  limit
#    shares of DOUG at  limit
# 70
#
# Order 45 :
#
# Order 48 : buy ing  190  shares of DOUG at  market
#  sell ing  133  shares of DOUG at  market
# 70
#
# Order 44 : buy ing  177  shares of DOUG at  market
# 70
#
# Order 44 : buy ing  54  shares of DOUG at  market
# 70
#
# Order 46 : 70buy  ing  43  shares of DOUG at  market
#
#
# Order 44 : sell ing  281  shares of DOUG at  limit
# 70
#
# Order 43 : buy ing  253  shares of DOUG at  market
# 7070
#
# Order 49 : buy ing  286  shares of DOUG at  market
#
#
# 70
#
# Order 44 : sell ing  137  shares of DOUG at  market70
#
# Order 45 : buy ing  7  shares of DOUG at  market
#
# Order7070 70
#
# Order 43 : sell ing  37  shares of DOUG at  market
#
#
# Order 46 : buy ing  99  shares of DOUG at  market
#  47
#
# Order 45 : sell ing  39  shares of DOUG at  market
# : sell ing  180  shares of DOUG at  limit
# 70
#
# Order 44 : buy ing  275  shares of DOUG at  limit
# 70
#
# Order 45 : buy ing  283  shares of DOUG at  limit
# 70
#
# Order 47 : buy ing  397  shares of DOUG at  market
# 70
#
# Order 47 : sell ing  195  shares of DOUG at  limit
# 7070
#
#
#
# Order 44 : sell ing  220  shares of DOUG at  limit
# 70
#
# Order 45 :70 sell
#
# Order 48 : sell ing  228  shares of DOUG at  limit
# 70 ing   276
#   shares of DOUG at
# 70Order 46 : sell ing  95  shares of DOUG at  market market
#
# 70
#
# Order 45
#
# Order 48 : sell ing  120  shares of DOUG at  limit
# 70: buy ing  253  shares of DOUG at  market
#  70
#
#
# Order 45 : buy ing  199  shares of DOUG at  limit
#
# Order 46 : sell ing  267  shares of DOUG at  market70
#
# Order 48 :
# sell 70
#
# Order ing 46 : buy ing  172  shares of DOUG at  limit
#  65  shares of DOUG at  market
# 70
# Order 46 : sell ing  153  shares of DOUG at  market
# 70
#
# Order 49 : buy ing  234  shares of DOUG at  market
# 70 70
#
# Order 46 : buy ing  287  shares of DOUG at  limit
#
#
# Order 46 : sell ing  63  shares of DOUG at  70
#
# Order 47 : sell ing  27  shares of DOUG at  limit
# limit
# 70
#
# Order 47 : sell ing  171  shares of DOUG at  market
# 70
#
# Order 49 : buy ing  190  shares of DOUG at  market
# 70
#
# Order 49 : sell ing  206  shares of DOUG at  limit
# 70
#
# Order 47 : sell ing  162  shares of DOUG at  limit
# 7070
#
#
#
# Order 47 : sell ing  96  shares of DOUG at  market
# 70
#
# Order 47 : sell ing  233  shares of DOUG at  market
# 70
#
# Order 47 : buy ing  365  shares of DOUG at  70
#
# market
# 70
#
# 7070
#
# Order 48 : sell ing  129  shares of DOUG at
# market
#
# Order 48 : buy ing  364  shares of DOUG at  limit
# 70 70
#
# Order 48 : sell ing  58  shares of DOUG at  limit
#
#
# Order 48 : sell ing  365  shares of DOUG at  market
# 70
#
# Order 48 : buy ing  235  shares of DOUG at  market
# 70
#
# Order 48 : sell ing  363  shares of DOUG at  market
# 70
#
# Order 49 : buy ing  156  shares of DOUG at  70market
#
#
# Order 49 : sell ing  153  shares of DOUG at  70
#
# Order 49 : market
# buy ing  131  shares of DOUG at  market
# 70
#
# Order 49 : sell ing  163  shares of DOUG at  market
# 70
#
# 7070
#
# Order 49 : sell ing   355  shares of DOUG at  limit
#
#
# Order 49 : buy ing  274  shares of DOUG at  limit
# 70
#
# 70
#
# 70
#
# 70
#
# 70

# %%
plt.plot(prices[:80])

# %%
# Get LOB snapshot
def LOBsnapshot():
    assetID = 1
    URL_snapshot = 'http://localhost:8080/api/' + str(assetID) + '/data/LOBSnapshot'
    snap_req = requests.get(url=URL_snapshot)
    data = json.loads(snap_req.text)
    print(data)

    x = []
    y = []
    for limit in data:
        x.append(limit['price'])
        y.append(limit['volume'])

#     plt.bar(x, y)

# %%
LOBsnapshot()

# %%
r = requests.get(url=URL_price)
price = r.json()
price
# Out:
# 41
